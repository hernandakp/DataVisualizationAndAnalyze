# %% [markdown]
# # Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016-2021

# %% [markdown]
# **Metode analisa yang digunakan**
#
# Langkah pelaksanaan penelitian dan analisis data adalah sebagai berikut:
# -	Mengumpulkan data produksi daging kambing berdasarkan kabupaten/kota di jawa barat tahun 2016-2021 yang dihasilkan oleh Dinas Ketahanan Pangan dan Peternakan yang dikeluarkan dalam periode 1 tahun sekali.
# -	Membuat diagram dan menganalisisnya.
# -	Menghitung rata-rata produksi daging kambing di seluruh kabupaten/kota di jawa barat periode tahun 2016-2021
#
# Dataset yang digunakan pada penelitian ini berisi data produksi daging kambing berdasarkan kabupaten/kota di jawa barat tahun 2016-2021. Dataset terkait topik ekonomi ini dihasilkan oleh Dinas Ketahanan Pangan dan Peternakan yang dikeluarkan dalam periode 1 tahun sekali.

# %%
'Author: hernanda472@gmail.com'

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset.csv')
df_2016 = df[df['tahun'] == 2016]
df_2017 = df[df['tahun'] == 2017]
df_2018 = df[df['tahun'] == 2018]
df_2019 = df[df['tahun'] == 2019]
df_2020 = df[df['tahun'] == 2020]
df_2021 = df[df['tahun'] == 2021]
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 157  158             32    JAWA BARAT                 3275
# 158  159             32    JAWA BARAT                 3276
# 159  160             32    JAWA BARAT                 3277
# 160  161             32    JAWA BARAT                 3278
# 161  162             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  produksi_daging    satuan  tahun
# 0       KABUPATEN BOGOR           434708  KILOGRAM   2016
# 1    KABUPATEN SUKABUMI           157449  KILOGRAM   2016
# 2     KABUPATEN CIANJUR           361834  KILOGRAM   2016
# ...

# %%
print("Gambar 1 Diagram Garis Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016-2021")
plt.figure(figsize=(10, 6))
plt.plot(df_2016['produksi_daging'], label='2016', marker = '.', color = 'red')
plt.plot(df_2017['produksi_daging'], label='2017', marker = '.', color = 'blue')
plt.plot(df_2018['produksi_daging'], label='2018', marker = '.', color = 'green')
plt.plot(df_2019['produksi_daging'], label='2019', marker = '.', color = 'brown')
plt.plot(df_2020['produksi_daging'], label='2020', marker = '.', color = 'slateblue')
plt.plot(df_2021['produksi_daging'], label='2021', marker = '.', color = 'magenta')
plt.title("Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016-2021", size=16)
plt.xlabel('id', size=14)
plt.ylabel('Produksi Daging Kambing (kg)', size=14)
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# Gambar 1 Diagram Garis Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016-2021

# %% [markdown]
# Berdasarkan diagram batang di atas, kita dapat melihat tampilan grafik diagram garis dengan sumbu x dan sumbu y. Sumbu x menyatakan id, sedangkan pada sumbu y menyatakan data produksi daging kambing dengan satuan kilogram.
#
# Pada grafik di atas tedapat grafik dengan 5 warna yang berbeda yaitu, grafik berwarna merah menyatakan tahun 2016, warna biru menyatakan tahun 2017, warna hijau menyatakan tahun 2018, warna coklat menyatakan tahun 2019, warna ungu menyatakan tahun 2020, dan warna merah muda menyatakan tahun 2020.
#
# Produksi daging kambing tertinggi yaitu terjadi di Kabupaten Bekasi pada tahun 2019 yang menghasilkan 4820511 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi pada tahun 2016, 2017, dan 2018 yang menghasilkan produksi yang hampir sama nilainya. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi pada tahun 2021.

# %%
print("Gambar 2 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016")
df_2016.plot(x="nama_kabupaten_kota", y="produksi_daging", kind='bar', figsize=(10, 6), color = 'red')
plt.title('Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016', size=16)
plt.ylabel('Produksi Daging Kambing (kg)', size=14)
plt.xlabel('Kabupaten/Kota', size=14)
# Out:
# Gambar 2 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016
# Text(0.5, 0, 'Kabupaten/Kota')

# %% [markdown]
# Berdasarkan diagram batang di atas, kita dapat melihat tampilan grafik diagram batang dengan sumbu x dan sumbu y. Sumbu x menyatakan nama-nama kabupaten/kota, sedangkan pada sumbu y menyatakan data produksi daging kambing dengan satuan kilogram.
#
# Pada grafik di atas kita dapat melihat tingkat produksi daging kambing di tiap kabupaten/kota di Provinsi Jawa Barat pada tahun 2016 sangat beragam nilainya. Produksi daging kambing tertinggi yaitu terjadi di Kota Bekasi yang menghasilkan 3632475 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 434708 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi di Kabupaten Bandung Barat, Kota Sukabumi, dan Kota Cimahi yang masing-masing menghasilkan 3294, 2868, dan 1544 kilogram produksi.

# %%
print("Gambar 3 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2017")
df_2017.plot(x="nama_kabupaten_kota", y="produksi_daging", kind='bar', figsize=(10, 6), color = 'blue')
plt.title('Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2017', size=16)
plt.ylabel('Produksi Daging Kambing (kg)', size=14)
plt.xlabel('Kabupaten/Kota', size=14)
# Out:
# Gambar 3 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2017
# Text(0.5, 0, 'Kabupaten/Kota')

# %% [markdown]
# Berdasarkan diagram batang di atas, kita dapat melihat tampilan grafik diagram batang dengan sumbu x dan sumbu y. Sumbu x menyatakan nama-nama kabupaten/kota, sedangkan pada sumbu y menyatakan data produksi daging kambing dengan satuan kilogram.
#
# Pada grafik di atas kita dapat melihat tingkat produksi daging kambing di tiap kabupaten/kota di Provinsi Jawa Barat pada tahun 2017 sangat beragam nilainya. Produksi daging kambing tertinggi yaitu terjadi di Kota Bekasi yang menghasilkan 3639875 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 2923796 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu menghasilkan 0 kilogram produksi atau sama sekali tidak menghasilkan produksi daging kambing, hal ini terjadi di Kota Depok.

# %%
print("Gambar 4 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2018")
df_2018.plot(x="nama_kabupaten_kota", y="produksi_daging", kind='bar', figsize=(10, 6), color = 'green')
plt.title('Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2018', size=16)
plt.ylabel('Produksi Daging Kambing (kg)', size=14)
plt.xlabel('Kabupaten/Kota', size=14)
# Out:
# Gambar 4 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2018
# Text(0.5, 0, 'Kabupaten/Kota')

# %% [markdown]
# Berdasarkan diagram batang di atas, kita dapat melihat tampilan grafik diagram batang dengan sumbu x dan sumbu y. Sumbu x menyatakan nama-nama kabupaten/kota, sedangkan pada sumbu y menyatakan data produksi daging kambing dengan satuan kilogram.
#
# Pada grafik di atas kita dapat melihat tingkat produksi daging kambing di tiap kabupaten/kota di Provinsi Jawa Barat pada tahun 2018 sangat beragam nilainya. Produksi daging kambing tertinggi yaitu terjadi di Kota Bekasi yang menghasilkan 3639882 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 2995385 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi di Kota Cimahi yang hanya menghasilkan 940 kilogram produksi.

# %%
print("Gambar 5 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2019")
df_2019.plot(x="nama_kabupaten_kota", y="produksi_daging", kind='bar', figsize=(10, 6), color = 'brown')
plt.title('Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2019', size=16)
plt.ylabel('Produksi Daging Kambing (kg)', size=14)
# Out:
# Gambar 5 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2019
# Text(0, 0.5, 'Produksi Daging Kambing (kg)')

# %% [markdown]
# Berdasarkan diagram batang di atas, kita dapat melihat tampilan grafik diagram batang dengan sumbu x dan sumbu y. Sumbu x menyatakan nama-nama kabupaten/kota, sedangkan pada sumbu y menyatakan data produksi daging kambing dengan satuan kilogram.
#
# Pada grafik di atas kita dapat melihat tingkat produksi daging kambing di tiap kabupaten/kota di Provinsi Jawa Barat pada tahun 2019 sangat beragam nilainya. Produksi daging kambing tertinggi yaitu terjadi di Kota Bekasi yang menghasilkan 4820511 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 347540 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi di Kota Cimahi yang hanya menghasilkan 47 kilogram produksi.

# %%
print("Gambar 1 6 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2020")
df_2020.plot(x="nama_kabupaten_kota", y="produksi_daging", kind='bar', figsize=(10, 6), color = 'slateblue')
plt.title('Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2020', size=16)
plt.ylabel('Produksi Daging Kambing (kg)', size=14)
plt.xlabel('Kabupaten/Kota', size=14)
# Out:
# Gambar 1 6 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2020
# Text(0.5, 0, 'Kabupaten/Kota')

# %% [markdown]
# Berdasarkan diagram batang di atas, kita dapat melihat tampilan grafik diagram batang dengan sumbu x dan sumbu y. Sumbu x menyatakan nama-nama kabupaten/kota, sedangkan pada sumbu y menyatakan data produksi daging kambing dengan satuan kilogram.
#
# Pada grafik di atas kita dapat melihat tingkat produksi daging kambing di tiap kabupaten/kota di Provinsi Jawa Barat pada tahun 2020 sangat beragam nilainya. Produksi daging kambing tertinggi yaitu terjadi di Kota Bekasi yang menghasilkan 3324682 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 370990 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu menghasilkan 0 kilogram produksi atau sama sekali tidak menghasilkan produksi daging kambing, hal ini terjadi di Kota Bandung.

# %%
print("Gambar 7 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2021")
df_2021.plot(x="nama_kabupaten_kota", y="produksi_daging", kind='bar', figsize=(10, 6), color = 'magenta')
plt.title('Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2021', size=16)
plt.ylabel('Produksi Daging Kambing (kg)', size=14)
plt.xlabel('Kabupaten/Kota', size=14)
plt.show()
# Out:
# Gambar 7 Diagram Batang Data Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2021

# %% [markdown]
# Berdasarkan diagram batang di atas, kita dapat melihat tampilan grafik diagram batang dengan sumbu x dan sumbu y. Sumbu x menyatakan nama-nama kabupaten/kota, sedangkan pada sumbu y menyatakan data produksi daging kambing dengan satuan kilogram.
#
# Pada grafik di atas kita dapat melihat tingkat produksi daging kambing di tiap kabupaten/kota di Provinsi Jawa Barat pada tahun 2021 sangat beragam nilainya. Produksi daging kambing tertinggi yaitu terjadi di Kota Bekasi yang menghasilkan 866768 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bekasi yang menghasilkan 284673 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu menghasilkan 0 kilogram produksi atau sama sekali tidak menghasilkan produksi daging kambing, hal ini terjadi di Kabupaten Sumedang dan Kota Bandung.

# %%
rerata = df_2016.loc[:, 'produksi_daging':].mean()
print("Rata-rata dari produksi daging kambing (kg) di tahun 2016 adalah:")
print(rerata)
rerata = df_2017.loc[:, 'produksi_daging':].mean()
print("Rata-rata dari produksi daging kambing (kg) di tahun 2017 adalah:")
print(rerata)
rerata = df_2018.loc[:, 'produksi_daging':].mean()
print("Rata-rata dari produksi daging kambing (kg) di tahun 2018 adalah:")
print(rerata)
rerata = df_2019.loc[:, 'produksi_daging':].mean()
print("Rata-rata dari produksi daging kambing (kg) di tahun 2019 adalah:")
print(rerata)
rerata = df_2020.loc[:, 'produksi_daging':].mean()
print("Rata-rata dari produksi daging kambing (kg) di tahun 2020 adalah:")
print(rerata)
rerata = df_2021.loc[:, 'produksi_daging':].mean()
print("Rata-rata dari produksi daging kambing (kg) di tahun 2021 adalah:")
print(rerata)
# Out:
# Rata-rata dari produksi daging kambing (kg) di tahun 2016 adalah:
# produksi_daging    273497.481481
# tahun                2016.000000
# dtype: float64
# Rata-rata dari produksi daging kambing (kg) di tahun 2017 adalah:
# produksi_daging    348026.074074
# tahun                2017.000000
# dtype: float64
# Rata-rata dari produksi daging kambing (kg) di tahun 2018 adalah:
# produksi_daging    375428.666667
# tahun                2018.000000
# dtype: float64
# Rata-rata dari produksi daging kambing (kg) di tahun 2019 adalah:
# produksi_daging    269645.851852
# tahun                2019.000000
# dtype: float64
# Rata-rata dari produksi daging kambing (kg) di tahun 2020 adalah:
# produksi_daging    214448.185185
# tahun                2020.000000
# dtype: float64
# Rata-rata dari produksi daging kambing (kg) di tahun 2021 adalah:
# produksi_daging    96209.814815
# tahun               2021.000000
# dtype: float64
# ...

# %% [markdown]
# Rata-rata dari produksi daging kambing di seluruh kabupaten/kota di jawa barat periode tahun 2016-2021 adalah sebagai berikut:
#
# a.	Tahun 2016: 273.497,481481 kilogram produksi
# b.	Tahun 2017: 348.026,074074 kilogram produksi
# c.	Tahun 2018: 375.428,666667 kilogram produksi
# d.	Tahun 2019: 269.645,851852 kilogram produksi
# e.	Tahun 2020: 214.448,185185 kilogram produksi
# f.	Tahun 2021: 96.209,814815 kilogram produksi

# %% [markdown]
# **Kesimpulan dan Saran**
#
# Berdasarkan analisis data dan pembahasan yang telah dilakukan dalam penelitian ini, maka dapat disimpulkan beberapa hal yakni:
#
# 1.	Terdapat 3 jenis visualisasi data yang dihasilkan yaitu diagram batang dan diagram garis.
# 2.	Produksi daging kambing tertinggi yaitu terjadi di Kabupaten Bekasi pada tahun 2019 yang menghasilkan 4820511 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi pada tahun 2016, 2017, dan 2018 yang menghasilkan produksi yang hampir sama nilainya. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi pada tahun 2021.
# 3.	Produksi daging kambing tertinggi pada tahun 2016 yaitu terjadi di Kota Bekasi yang menghasilkan 3632475 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 434708 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi di Kabupaten Bandung Barat, Kota Sukabumi, dan Kota Cimahi yang masing-masing menghasilkan 3294, 2868, dan 1544 kilogram produksi.
# 4.	Produksi daging kambing tertinggi pada tahun 2017 yaitu terjadi di Kota Bekasi yang menghasilkan 3639875 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 2923796 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu menghasilkan 0 kilogram produksi atau sama sekali tidak menghasilkan produksi daging kambing, hal ini terjadi di Kota Depok.
# 5.	Produksi daging kambing tertinggi pada tahun 2018 yaitu terjadi di Kota Bekasi yang menghasilkan 3639882 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 2995385 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi di Kota Cimahi yang hanya menghasilkan 940 kilogram produksi.
# 6.	Produksi daging kambing tertinggi pada tahun 2019 yaitu terjadi di Kota Bekasi yang menghasilkan 4820511 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 347540 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu terjadi di Kota Cimahi yang hanya menghasilkan 47 kilogram produksi.
# 7.	Produksi daging kambing tertinggi pada tahun 2020 yaitu terjadi di Kota Bekasi yang menghasilkan 3324682 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bogor yang menghasilkan 370990 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu menghasilkan 0 kilogram produksi atau sama sekali tidak menghasilkan produksi daging kambing, hal ini terjadi di Kota Bandung.
# 8.	Produksi daging kambing tertinggi pada tahun 2021 yaitu terjadi di Kota Bekasi yang menghasilkan 866768 kilogram produksi, sedangkan produksi daging kambing tertinggi kedua yaitu terjadi di Kabupaten Bekasi yang menghasilkan 284673 kilogram produksi. Adapun produksi daging kambing terendah di Provinsi Jawa Barat yaitu menghasilkan 0 kilogram produksi atau sama sekali tidak menghasilkan produksi daging kambing, hal ini terjadi di Kabupaten Sumedang dan Kota Bandung.
# 9.	Rata-rata dari produksi daging kambing di seluruh kabupaten/kota di jawa barat periode tahun 2016-2021 adalah sebagai berikut:
# a.	Tahun 2016: 273.497,481481 kilogram produksi
# b.	Tahun 2017: 348.026,074074 kilogram produksi
# c.	Tahun 2018: 375.428,666667 kilogram produksi
# d.	Tahun 2019: 269.645,851852 kilogram produksi
# e.	Tahun 2020: 214.448,185185 kilogram produksi
# f.	Tahun 2021: 96.209,814815 kilogram produksi
#
# Agar program yang dapat digunakan lebih optimal dan dapat berjalan sesuai dengan yang diharapkan, maka ada beberapa saran yang dapat dijadikan bahan pertimbangan untuk pembaca. Adapun saran yang peneliti berikan adalah sebagai berikut:
# 1.	Sistem yang dibangun pada intinya hanya sebatas dataset Produksi Daging Kambing Berdasarkan Kabupaten/Kota di Jawa Barat Tahun 2016-2021. Sehingga diharapkan adanya pengembangan lagi untuk sistem yang lebih luas cakupannya.
# 2.	Diperlukan maintenace terhadap program aplikasi yang telah dibuat, supaya dapat digunakan secara berkelanjutan sesuai kebutuhan.
# 3.	Pahami data yang akan dianalisis, sebagai acuan dalam pemilihan bahasa pemograman.
